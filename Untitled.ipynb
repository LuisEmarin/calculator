# %%
from IPython.display import clear_output

class Investment():
    """
    Income
    Expenses
    Cash Flow
    Cash on Cash ROI
    """
lit= []    
def __init__(self,income, expenses, cashFlow, cashOncashRoI):
    self.income = income
    self.expenses = expenses
    self.cashFlow = cashFlow
    self.cashOncash = cashOncash


def getINc(self):
    clear_output()
income = int(input("What is your estimated rental income?$"))
getINc = income

def exPENses(self):
    lit = []
tax = int(input("How much are your estimated monthly taxes? A good starting point would be $150:$"))
lit.append(tax)
insur = float(input("How much is your insurance cost? A good estimate would be $100:$"))
lit.append(insur)    
Hoa = float(input('If any, how much are your HoA fees? If none input 0'))
lit.append(Hoa)
outside = float(input('How much will you spend on lawn/snow care? If none input 0: $'))
lit.append(outside)
util = float(input("How much do you estimate your utilities to be? If none input 0: $"))
lit.append(util)
repairs = float(input("how much are you going to put aside each month for repairs? $100 is a recommended amount. If none input 0: $"))
lit.append(repairs)
capEx = float(input(" How much will you set aside monthly for capital expenses?(Anything that will prolong the life of the building) $100 is a recommended amount. If none input 0: $"))
lit.append(capEx)
propmng = float(input('How much will you spend on property management? If none input 0: $'))
lit.append(propmng)
mort = float(input("What is your estimated mortgage?"))
lit.append(mort)


    
expenses = sum(lit)
print(f'Your monthy expenses are : {expenses}')
def cashFlow(self):
    clear_output()
cashFlow = getINc - expenses
print(f' Your monthly cash flow is {cashFlow}')

def cashONcash(self):
    clear_output()
downpayment = float(input('How much are you going to put down on your mortgage?:$'))
closing = float(input('How much are your closing costs? The national average is typically .5 of your loan:$'))
ask = input('Do you plan to rehab this property? yes/no')
if ask.lower() == 'no':
    pass
else:
        "yes"
rehab = float(input('How much do you plan to spend?'))

totalinvestment = downpayment + closing + rehab
print(f'Your total investment is {totalinvestment}')
        
        
        
def RoI():
    
    annualreturn = cashFlow * 12
    print('Your yearly cash flow is {annualreturn}')
RoI = (annualreturn / totalinvestment)
print(f'Your return on investment percentage is {RoI})
# Out:
# What is your estimated rental income?$2000
# How much are your estimated monthly taxes? A good starting point would be $150:$150
# How much is your insurance cost? A good estimate would be $100:$100
# If any, how much are your HoA fees? If none input 00
# How much will you spend on lawn/snow care? If none input 0: $200
# How much do you estimate your utilities to be? If none input 0: $0
# how much are you going to put aside each month for repairs? $100 is a recommended amount. If none input 0: $100
#  How much will you set aside monthly for capital expenses?(Anything that will prolong the life of the building) $100 is a recommended amount. If none input 0: $100
# How much will you spend on property management? If none input 0: $0
# What is your estimated mortgage?1300
# Your monthy expenses are : 1950.0
#  Your monthly cash flow is 50.0
# How much are you going to put down on your mortgage?:$5000
# ...
